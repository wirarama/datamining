# %%
# %matplotlib inline
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
n_samples = 50000
n_components = 10

X, y_true = make_blobs(n_samples=n_samples,
                       centers=n_components,
                       cluster_std=0.60,
                       random_state=0)
X = X[:, ::-1]

# %%
print(X)
# Out:
# [[ 1.7172997   2.05171108]
#  [ 3.85982582  1.78184328]
#  [ 3.82362844 -1.25291854]
#  ...
#  [ 4.93664208  1.12686895]
#  [ 2.76528653 -1.24487739]
#  [ 2.57752318 -1.80660097]]

# %%
C = KMeans(n_clusters=10,random_state=0,init='k-means++').fit(X)
centers_init = C.cluster_centers_

# %%
plt.figure(1)
colors = ['#4EACC5', '#FF9C34', '#4E9A06', '#124537','#4EAC12', '#F17C34', '#4E1506','#4E19C5', '#FF9124', '#4E6506']

for k, col in enumerate(colors):
    cluster_data = y_true == k
    plt.scatter(X[cluster_data, 0], X[cluster_data, 1],
                c=col, marker='.', s=10)

plt.scatter(centers_init[:, 0], centers_init[:, 1], c='b', s=50)
plt.title("K-Means++ Initialization")
plt.xticks([])
plt.yticks([])
plt.show()
